# %%
suppressWarnings(
  suppressPackageStartupMessages({
    library(misha)
    library(misha.ext)
    library(zoo)
    library(tglkmeans)
    library(data.table)
    library(tidyverse)
    library(tgstat)
    library(prego)
    library(tgutil)
    library(here)
    library(pheatmap)
  })
)

options(gmax.data.size = 1e10)
options(gmultitasking = FALSE)

link_dir =  paste0(here(),'/')
setwd(here())
gsetroot(paste0(link_dir,'data/mm10/'))
gdb.reload()

source(paste0(link_dir,'code/seq2epi_utils.r'))
source(paste0(link_dir,'code/fig_fun.r'))



mod = init_pipe()
# Out:
# done track quant
#
# done cnt track quant
#
# done lib

# %% [markdown]
# **PcG and TrxG differentiation in the epiblast is correlated with distal CRE accessibility.**

# %% [markdown]
# **Fig. 6A, E, and F. In vivo mesoderm differentiation.**

# %%
fig6_diff_cres(mod=mod,nm1_a = 'atac_e75_epi',#'multeb_epi'  #'atac_e75_epi'
nm2_a ='atac_e75_exe_meso', #'multeb_meso' # 'atac_e75_exe_meso'

nm1 = 'e75_ecto_cnt_n', #EB5_epi_cnt_n 'e75_ecto_cnt_n' 
nm2 = 'e75_emeso_cnt_n') #EB5_meso_cnt_n       'e75_emeso_cnt_n')
# Out:
# set vt for marginal
#
# ./data/files//atac_mat_invivo_fig6.rds
# [1] "e75_emeso_cnt_n_loss"
# [1] "e75_ecto_cnt_n_loss"
# plot without title
#                 cons  e75_ecto_cnt_n_loss e75_emeso_cnt_n_loss
#                 4369                    7                  275
#                 else                   k4
#                 5867                 8346
#
#       [0,100]   (100,1e+03] (1e+03,4e+03] (4e+03,1e+04] (1e+04,2e+04]
#          3765           736          1449          2054          3964
# (2e+04,5e+04] (5e+04,1e+05] (1e+05,2e+05] (2e+05,5e+05] (5e+05,5e+09]
#          9630         12434         18562         34607        162501
# plot without title
# plot without title
# plot without title

# %% [markdown]
# **Fig. 6B, E, and G. In vitro mesoderm differentiation.**

# %%
fig6_diff_cres(mod=mod,nm1_a = 'multeb_epi' ,#'multeb_epi'  #'atac_e75_epi'
nm2_a ='multeb_meso', #'multeb_meso' # 'atac_e75_exe_meso'

nm1 = 'EB5_epi_cnt_n', #EB5_epi_cnt_n 'e75_ecto_cnt_n' 
nm2 = 'EB5_meso_cnt_n') #EB5_meso_cnt_n       'e75_emeso_cnt_n')
# Out:
# set vt for marginal
#
# ./data/atac_mat_meeb_fig6.rds
# [1] "EB5_meso_cnt_n_loss"
# [1] "EB5_epi_cnt_n_loss"
# plot without title
#                cons  EB5_epi_cnt_n_loss EB5_meso_cnt_n_loss                else
#                4320                 147                 216                6604
#                  k4
#                7577
#
#       [0,100]   (100,1e+03] (1e+03,4e+03] (4e+03,1e+04] (1e+04,2e+04]
#          5810          1717          2659          4129          6296
# (2e+04,5e+04] (5e+04,1e+05] (1e+05,2e+05] (2e+05,5e+05] (5e+05,5e+09]
#         15396         20232         29754         49268        211397
# plot without title
# plot without title
# plot without title

# %% [markdown]
# **Fig. 6B and D. And some additional examples of genomic regions.**

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Cdkn2a',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('e75_ecto_cnt_n','e75_emeso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 =5.5e4,marg3 =4.5e4,ds_k27 = F )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 5.5e4,marg3 =4.5e4,ds_k27 = F ),'./figs/fig5_Cdkn2a_invivo.pptx')
# Out:
# [1] 1 6
# [1] 8.839532
# [1] 8.839532
# Plot with title “e75_emeso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Cdkn2a',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 5.5e4,marg3 =4.5e4,ds_k27 = F )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 5.5e4,marg3 =4.5e4,ds_k27 = F ),'./figs/fig5_Cdkn2a_eb_meso.pptx')
# Out:
# [1] 1 6
# [1] 8.201487
# [1] 8.201487
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Foxo1',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 4e4,marg3 =1.5e4,ds_k27 = F )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 4e4,marg3 =1.5e4,ds_k27 = F ),'./figs/fig5_Foxo1_eb_meso.pptx')
# Out:
# [1] 1 6
# [1] 6.846106
# [1] 6.846106
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Snai1',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 4e4,marg3 =9e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 4e4,marg3 =9e4,ds_k27 = T ),'./figs/fig5_Snai1.pptx')
# Out:
# [1] 1 6
# [1] 7.089693
# [1] 7.089693
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Mixl1',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =5e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =5e4,ds_k27 = T ),'./figs/fig5_Mixl1.pptx')
# Out:
# [1] 1 6
# [1] 7.079484
# [1] 7.079484
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Mesp2',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 9e4,marg3 =9e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 9e4,marg3 =9e4,ds_k27 = T ),'./figs/fig5_Mesp2.pptx')
# Out:
# [1] 1 6
# [1] 7.915081
# [1] 7.915081
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Kdr',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 2e4,marg3 =2e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 2e4,marg3 =2e4,ds_k27 = T ),'./figs/fig5_Kdr_EB.pptx')
# Out:
# [1] 1 6
# [1] 7.354925
# [1] 7.354925
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Kdr',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('e75_ecto_cnt_n','e75_emeso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =3e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =3e4,ds_k27 = T ),'./figs/fig5_Kdr.pptx')
# Out:
# [1] 1 6
# [1] 7.821815
# [1] 7.821815
# Plot with title “e75_emeso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Mesp1',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('EB5_epi_cnt_n','EB5_meso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 100 ,mark_seeds = F,
                     marg5 = 1e5,marg3 =1e5,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 100 ,mark_seeds = F,
                     marg5 = 1e5,marg3 =1e5,ds_k27 = T ),'./figs/fig5_Mesp1.pptx')
# Out:
# [1] 1 6
# [1] 7.579331
# [1] 7.579331
# Plot with title “EB5_meso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Hand2',]
dim(temp)
temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end
options( repr.plot.width=8,repr.plot.height=8)
take = c('e75_ecto_cnt_n','e75_emeso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =5.5e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = st,end =en,k = 1 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =5.5e4,ds_k27 = T ),'./figs/fig5_Hand2.pptx')
# Out:
# [1] 1 6
# [1] 9.04047
# [1] 9.04047
# Plot with title “e75_emeso_cnt_n”

# %%
temp = mod$tss[ mod$tss$geneSymbol=='Hand1',]

temp = temp[1,]

chr = temp$chrom
st = temp$start
en = temp$end

take = c('e75_ecto_cnt_n','e75_emeso_cnt_n')
options( repr.plot.width=8,repr.plot.height=8)
plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st = en,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =3e4,ds_k27 = T )
save_baseR_to_ppt(plt_region_per_tr(mod = mod,track_names = take,mark = st,chr = chr,st =st,end =en,k = 50 ,mark_seeds = F,
                     marg5 = 3e4,marg3 =3e4,ds_k27 = T ),'./figs/fig5_Hand1.pptx')
# Out:
# [1] 8.623497
# [1] 8.623497
# Plot with title “e75_emeso_cnt_n”
