# %%
library("misha")
library("misha.ext")
library("zoo")
library("tglkmeans")
library("misha.ext")
library(here)
library(tidyverse)
library(tgstat)

#gdb.reload()
options(gmax.data.size = 1e10)
options(gmultitasking = FALSE)






link_dir =  paste0(here(),'/')
setwd(here())
gsetroot(paste0(link_dir,'data/mm10/'))
gdb.reload()

# %%
getwd()
# Out:
# [1] "/net/mraid20/ifs/wisdom/tanay_lab/tgdata/users/evghenic/Proj/polycomb/seq2epi_paper_norm"

# %%
source('./code/sns_cnt_atac_norm.r')

# %%
sns = create_sns_conf_mm()

# %%
sns$conf$k27_track_nm
# Out:
# [1] "jk.epipcg.pcg.CRJK_0364_k27me3_eb_j1_d4_a"

# %%
gtrack.ls('jk.epipcg.pcg')
# Out:
#  [1] "jk.epipcg.pcg.CRJK_0211_k27me3_es_50k"
#  [2] "jk.epipcg.pcg.CRJK_0232_k27me3_es_2i_dmso"
#  [3] "jk.epipcg.pcg.CRJK_0293_k27me3_j1_eb_d5_epi"
#  [4] "jk.epipcg.pcg.CRJK_0294_k27me3_j1_eb_d5_meso"
#  [5] "jk.epipcg.pcg.CRJK_0295_k27me3_j1_eb_d5_endo"
#  [6] "jk.epipcg.pcg.CRJK_0321_k27me3_e75_ecto"
#  [7] "jk.epipcg.pcg.CRJK_0322_k27me3_e75_endo"
#  [8] "jk.epipcg.pcg.CRJK_0323_k27me3_e75_meso"
#  [9] "jk.epipcg.pcg.CRJK_0324_k27me3_e75_e_meso"
# [10] "jk.epipcg.pcg.CRJK_0361_k27me3_e7_meso"
# [11] "jk.epipcg.pcg.CRJK_0362_k27me3_e7_ps"
# [12] "jk.epipcg.pcg.CRJK_0363_k27me3_eb_j1_d3_a"
# [13] "jk.epipcg.pcg.CRJK_0364_k27me3_eb_j1_d4_a"
# [14] "jk.epipcg.pcg.CRJK_0365_k27me3_eb_dko_d3_a"
# [15] "jk.epipcg.pcg.CRJK_0403_k27me3_wt_to_wt_eb_d3"
# [16] "jk.epipcg.pcg.CRJK_0407_k27me3_dko_to_dko_eb_d3"
# [17] "jk.epipcg.pcg.CRJK_0408_k27me3_dko_to_dko_eb_d4"
# [18] "jk.epipcg.pcg.CRJK_0411_k4me3_wt_to_wt_eb_d3"
# [19] "jk.epipcg.pcg.CRJK_0413_k4me3_dko_to_dko_eb_d3"
# ...

# %%
paste0(sns$conf$k27_track_nm,'_norm')
sns$conf$k27_track_nm
# Out:
# [1] "jk.epipcg.pcg.CRJK_0364_k27me3_eb_j1_d4_a_norm"
# [1] "jk.epipcg.pcg.CRJK_0364_k27me3_eb_j1_d4_a"

# %%
##eb4 just withou adding 5 k_add
sns_gen_cnt_norm_track(out_tn = paste0(sns$conf$k27_track_nm,'_kadd1_norm'), cnt_tn = sns$conf$k27_track_nm, 
                       atac_tn = sns$conf$atac_track_nm, 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 1,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = sns$conf$k27_track_nm, atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
sns$conf$atac_track_nm
# Out:
# [1] "jk.epipcg.atac.CRJK_0389_atac_wt_to_wt_eb_d3"

# %%
sns_gen_cnt_norm_track(out_tn = paste0(sns$conf$k27_track_nm,'_norm'), cnt_tn = sns$conf$k27_track_nm, 
                       atac_tn = sns$conf$atac_track_nm, 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = sns$conf$k27_track_nm, atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

# %%
plot(normalizer$trend)
# Out:
# plot without title

# %%
normalizer = sns_gen_cnt_normalizer(cnt_tn = sns$conf$k27_track_nm, atac_tn = 'jk.epipcg.multieb.marginal',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0408_k27me3_dko_to_dko_eb_d4",'_norm'), 
                       cnt_tn ="jk.epipcg.pcg.CRJK_0408_k27me3_dko_to_dko_eb_d4", 
                       atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0408_k27me3_dko_to_dko_eb_d4", 
                                    atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

# %%
gtrack.ls('marginal')
# Out:
# [1] "jk.epipcg.multieb.marginal"        "jk.epipcg.multieb.marginal_regcap"
# [3] "jk.epipcg.multieb24.marginal"      "mut_multi.WT_E70.marginal"
# [5] "mut_multi.WT_E75.marginal"

# %%
plot(normalizer$trend)
# Out:
# plot without title

# %%
gsummary('jk.epipcg.pcg.CRJK_0364_k27me3_eb_j1_d4_a_norm')
# Out:
# Total intervals   NaN intervals             Min             Max             Sum
#    1.362769e+08    0.000000e+00    1.987833e+00    1.016191e+01    6.785889e+08
#            Mean         Std dev
#    4.979486e+00    5.283754e-01

# %%
'jk.epipcg.pcg.CRJK_0363_k27me3_eb_j1_d3_a',
 
  'jk.epipcg.pcg.CRJK_0365_k27me3_eb_dko_d3_a'

# %%
'jk.epipcg.pcg.CRJK_0407_k27me3_dko_to_dko_eb_d3'

# %%
sns_gen_cnt_norm_track(out_tn = paste0('jk.epipcg.pcg.CRJK_0407_k27me3_dko_to_dko_eb_d3','_norm'), 
                       cnt_tn ='jk.epipcg.pcg.CRJK_0407_k27me3_dko_to_dko_eb_d3', 
                       atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = 'jk.epipcg.pcg.CRJK_0407_k27me3_dko_to_dko_eb_d3', 
                                    atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0365_k27me3_eb_dko_d3_a",'_norm'), 
                       cnt_tn ="jk.epipcg.pcg.CRJK_0365_k27me3_eb_dko_d3_a", 
                       atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0365_k27me3_eb_dko_d3_a", 
                                    atac_tn = 'jk.epipcg.atac.CRJK_0400_atac_dko_to_dko_eb_d4',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
sns$conf$atac_track_nm
sns_gen_cnt_norm_track(out_tn = paste0('jk.epipcg.pcg.CRJK_0363_k27me3_eb_j1_d3_a','_norm'), cnt_tn = 'jk.epipcg.pcg.CRJK_0363_k27me3_eb_j1_d3_a', 
                       atac_tn = sns$conf$atac_track_nm, 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = 'jk.epipcg.pcg.CRJK_0363_k27me3_eb_j1_d3_a', atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# [1] "jk.epipcg.atac.CRJK_0389_atac_wt_to_wt_eb_d3"
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0321_k27me3_e75_ecto",'_norm'),
                       cnt_tn ="jk.epipcg.pcg.CRJK_0321_k27me3_e75_ecto", 
                       atac_tn = "mut_multi.WT_E75.marginal", 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0321_k27me3_e75_ecto", 
                                    atac_tn = "mut_multi.WT_E75.marginal",
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# [1] "jk.epipcg.atac.CRJK_0389_atac_wt_to_wt_eb_d3"
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0324_k27me3_e75_e_meso",'_norm'),
                       cnt_tn ="jk.epipcg.pcg.CRJK_0324_k27me3_e75_e_meso", 
                       atac_tn = "mut_multi.WT_E75.marginal", 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0324_k27me3_e75_e_meso", 
                                    atac_tn = "mut_multi.WT_E75.marginal",
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0324_k27me3_e75_e_meso", 
                                    atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

# %%
plot(normalizer$trend)
# Out:
# plot without title

# %%
jk.epipcg.pcg.CRJK_0293_k27me3_j1_eb_d5_epi	
jk.epipcg.pcg.CRJK_0294_k27me3_j1_eb_d5_meso
'jk.epipcg.multieb24.mcEpiblast','jk.epipcg.multieb24.mcn_meso',

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0293_k27me3_j1_eb_d5_epi",'_norm'),
                       cnt_tn ="jk.epipcg.pcg.CRJK_0293_k27me3_j1_eb_d5_epi", 
                       atac_tn ='jk.epipcg.multieb24.mcEpiblast', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0293_k27me3_j1_eb_d5_epi", 
                                    atac_tn ='jk.epipcg.multieb24.mcEpiblast',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0("jk.epipcg.pcg.CRJK_0294_k27me3_j1_eb_d5_meso",'_norm'),
                       cnt_tn ="jk.epipcg.pcg.CRJK_0294_k27me3_j1_eb_d5_meso", 
                       atac_tn ='jk.epipcg.multieb24.mcn_meso', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = "jk.epipcg.pcg.CRJK_0294_k27me3_j1_eb_d5_meso", 
                                    atac_tn ='jk.epipcg.multieb24.mcn_meso',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
'jk.epipcg.pcg.CRJK_0295_k27me3_j1_eb_d5_endo'
'jk.epipcg.multieb24.mcGut'

# %%
sns_gen_cnt_norm_track(out_tn = paste0('jk.epipcg.pcg.CRJK_0295_k27me3_j1_eb_d5_endo','_norm'),
                       cnt_tn ='jk.epipcg.pcg.CRJK_0295_k27me3_j1_eb_d5_endo', 
                       atac_tn ='jk.epipcg.multieb24.mcGut', 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = 'jk.epipcg.pcg.CRJK_0295_k27me3_j1_eb_d5_endo', 
                                    atac_tn ='jk.epipcg.multieb24.mcGut',
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# Error in file(con, "rb"): cannot open the connection
# Traceback:
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0('jk.epipcg.pcg.CRJK_0211_k27me3_es_50k','_norm'), cnt_tn = 'jk.epipcg.pcg.CRJK_0211_k27me3_es_50k', 
                       atac_tn = sns$conf$atac_track_nm, 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = 'jk.epipcg.pcg.CRJK_0211_k27me3_es_50k', atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title

# %%
sns_gen_cnt_norm_track(out_tn = paste0('jk.epipcg.pcg.CRJK_0232_k27me3_es_2i_dmso','_norm'), cnt_tn = 'jk.epipcg.pcg.CRJK_0232_k27me3_es_2i_dmso', 
                       atac_tn = sns$conf$atac_track_nm, 
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													k_add = 5,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")

normalizer = sns_gen_cnt_normalizer(cnt_tn = 'jk.epipcg.pcg.CRJK_0232_k27me3_es_2i_dmso', atac_tn = sns$conf$atac_track_nm,
													cnt_k_reg = 6, atac_k_reg = 1,
													win = 300,
													line_interv_nm = "intervs.global.rmsk_line", 
													ltr_interv_nm = "intervs.global.rmsk_ltr")
plot(normalizer$trend)
# Out:
# plot without title
